# %% [markdown]
# # Simple test
#
# First notebook in https://github.com/bjdean/data-analytics - built via https://github.com/features/codespaces
#
# Flicking idly through data in https://data.gov.au/ found [Brisbane Food Trucks](https://data.gov.au/dataset/ds-brisbane-7f045b34-36c5-48e8-ab7b-3f8d44d20619/details) - seems like a random fun place to start.
#
# ## Setup
#
# 1. First python execution prompted installing "Python + Jupyter" extensions in the Command Palette - accepted prompt.
# 1. Then needed to select a Jupyter notebook kernel (top-right) - not existing

# %%
import pandas as pd

data_url = 'https://www.bnefoodtrucks.com.au/api/1/trucks'

data = pd.read_json(data_url)

data.head()
# Out:
#    truck_id                    name  category  \
# 0        66       King of the Wings  American
# 1        71            Koma Sliders    Korean
# 2        91            Nom Nom Eats   Tex-mex
# 3        96     Rolling Stone Pizza     Pizza
# 4       106  Catch and Kiss Seafood   Seafood
#
#                                                  bio  \
# 0  International award winning Food truck. Austra...
# 1  "It's Korean.  It's American. It's Slider-lici...
# 2
# 3  The heat of our authentic wood-fired oven is m...
# 4  Catch and Kiss started in Brisbane and in a sh...
#
#                                               avatar  \
# 0  {'src': 'https://www.bnefoodtrucks.com.au/site...
# 1  {'src': 'https://www.bnefoodtrucks.com.au/site...
# 2  {'src': 'https://www.bnefoodtrucks.com.au/site...
# 3  {'src': 'https://www.bnefoodtrucks.com.au/site...
# 4  {'src': 'https://www.bnefoodtrucks.com.au/site...
#
#                                          cover_photo  \
# ...

# %%
data.columns
# Out:
# Index(['truck_id', 'name', 'category', 'bio', 'avatar', 'cover_photo',
#        'website', 'facebook_url', 'instagram_handle', 'twitter_handle'],
#       dtype='object')

# %%
data.category.value_counts()
# Out:
# category
# Dessert / Sweet          34
# Burger                   13
# American                  9
# Pizza                     8
# Asian                     8
# BBQ / Meat Enthusiast     6
# Healthy                   5
# German                    5
# Fusion                    5
# Indian                    4
#                           4
# Turkish                   4
# Mexican                   4
# Juice                     3
# Sri Lankan                3
# Italian                   3
# Australian                3
# South American            3
# Japanese                  3
# African                   2
# Vegan                     2
# Greek                     2
# Korean                    2
# French                    2
# Vietnamese                2
# Seafood                   2
# Hotdogs                   1
# Thai                      1
# Gluten free               1
# Kebab                     1
# Malaysian                 1
# Tex-mex                   1
# ...

# %%
data.category.value_counts().plot(
    title = 'Types of trucks',
    kind='pie',
    )
# Out:
# <Axes: title={'center': 'Types of trucks'}, ylabel='count'>
